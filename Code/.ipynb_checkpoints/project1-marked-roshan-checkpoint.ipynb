# %% [markdown]
# <div style="border: 1px solid thistle; padding: 5px 20px 10px 20px;">
#     <h2><font color = "77658f" style=";"> Feedback </font></h2><br>
#     <font color = "77658f"> Important to define problem statement and make sure it is addressed in conclusion section. For filtering and masking for dataframes, not necessary to include groupby as no aggregation is required. Do ensure that all visuals are interpreted. <br><br>
#         • Project Organisation: <b>1</b> <br>
#         • Clarity of Message: <b>2</b> <br>
#         • Python Syntax and Control Flow: <b>2</b><br>
#         • Data Cleaning and EDA: <b>2</b><br>
#         • Visualisations: <b>1</b><br>
#         • Research and Conceptual Understanding: <b>2</b><br>
#         • Presentation: <b>2</b><br>
#     </font>
# </div>

# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# Define the problem you are finding answers for from the data given.

# %% [markdown]
# > <font size = 3 color = "crimson"> No problem statement</font>

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
# Out:
# /Users/ryanchangky/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# > <font size = 3 color = "crimson"> Good work in importing the libraries and initializing style settings</font>

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
act_2017 = pd.read_csv('../data/act_2017.csv')
sat_2017 = pd.read_csv('../data/sat_2017.csv')

# %% [markdown]
# > <font size = 3 color = "crimson"> Good use of relative path when reading csv files</font>

# %%
# Check type to ensure its in DataFrame
type(act_2017)
# Out:
# pandas.core.frame.DataFrame

# %%
type(sat_2017)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Print out the first 10 rows for ACT 2017 dataset to examine what it looks like
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
##Print out the first 10 rows for SAT 2017 dataset to examine what it looks like
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# 8   468    950
# 9   497   1017

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %%
print(act_2017.shape)
print(sat_2017.shape)
# Out:
# (52, 7)
# (51, 5)

# %%
print(act_2017.columns)
print(sat_2017.columns)
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %% [markdown]
# Both ACT and SAT data set shows the particpation rate of high students per State across USA.
# Their rows indicate the name of the States.
#
# ACT data has 7 columns which is made up of State, Participation(rate), English, Math, Science, Reading and Composite(Average).
# The Participation rate is shown in percentage, while English, Math, Science, Reading columns indicate the average score for each subject.
# Composite column is the average score for English, Math, Science and Reading.
#
# Meanwhile SAT data has 5 columns which is made up of State, Participation(rate), Evidence-Based Reading and Writing, Math and Total.
# The Participation rate is shown in percentage, while Evidence-Based Reading and Writing and Math column indicate the average score for each subject.
# Total column is made up of the sum of average score for Evidence-Based Reading and Writing and Math.

# %% [markdown]
# > <font size = 3 color = "crimson"> Include the data types of each column too.</font>

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# > <font size = 3 color = "crimson"> Do also show your working: df.isnull().sum() </font>

# %% [markdown]
# The data does look complete, however I notice unlike the SAT data set ACT data set has an additional
# row for the national figure.

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# ACT
# Participation which is calculated in percentage has a minimum possible value of 0 and maximum possible
# value of 1 (100%).
# For English, Math, Reading and Science the Overall Score Range is 1 (minimum) to 36 (maximum).
# Composite which is the mean English, Math, Reading and Science the Overall Score Range is 1 (minimum)
# to 36 (maximum).
#
# Ref: https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html

# %% [markdown]
# SAT
# Participation which is calculated in percentage has a minimum possible value of 0 and maximum possible
# value of 1 (100%).
# For Evidence-Based Reading and Writing, Math the Overall score range is from 200 (minimum)
# to 800 (maximum).
#
# Ref:https://collegereadiness.collegeboard.org/sat/scores/understanding-scores/structure

# %%
#Min and Max result for English, Math, Reading and Science
#Composite and Particpation is currently an object dtype will check in Qn 6
#Notice a score value of 2.3 in the Science Column, eventhough its in the range will double check
print('Minimum Possible Value')
print(act_2017[['English', 'Math', 'Reading', 'Science']].min())
print('Maximum Possible Value')
print(act_2017[['English', 'Math', 'Reading', 'Science']].max())
# Out:
# Minimum Possible Value
# English    16.3
# Math       18.0
# Reading    18.1
# Science     2.3
# dtype: float64
# Maximum Possible Value
# English    25.5
# Math       25.3
# Reading    26.0
# Science    24.9
# dtype: float64

# %%
# Min and Max result for Evidence-Based Reading and Writing, Math
# Particpation is currently an object dtype will check once dtype is amended to float in Qn 6
# Notice a score value of 52 in the Math Column is below the range
print('Minimum Possible Value')
print(sat_2017[['Evidence-Based Reading and Writing', 'Math']].min())
print('Maximum Possible Value')
print(sat_2017[['Evidence-Based Reading and Writing', 'Math']].max())
# Out:
# Minimum Possible Value
# Evidence-Based Reading and Writing    482
# Math                                   52
# dtype: int64
# Maximum Possible Value
# Evidence-Based Reading and Writing    644
# Math                                  651
# dtype: int64

# %% [markdown]
# > <font size = 3 color = "crimson"> Identified all the errors correctly.</font>

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
# Extract row showing the incorrect value for SAT Math 
sat_2017[sat_2017['Math'] <= 52]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %%
# Amend the Math data value for Maryland to 524
sat_2017.loc[20,'Math'] = sat_2017.iloc[20,4] - sat_2017.iloc[20,2]
sat_2017.iloc[18:21]
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 18  Louisiana            4%                                 611   586   1198
# 19      Maine           95%                                 513   499   1012
# 20   Maryland           69%                                 536   524   1060

# %%
# Extract the row with the outlier of 2.3 for Science
act_2017[act_2017['Science'] == 2.3]
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2      2.3      23.6

# %%
# Average Total Composite * 4 = 94.4
# Avg total less sum of English, Math and REading = 23.8
act_2017.iloc[21,5] = (float(act_2017.iloc[21,6])*4) - np.sum(act_2017.iloc[21,2:5])
act_2017.iloc[18:22]
# Out:
#         State Participation  English  Math  Reading  Science Composite
# 18   Kentucky          100%     19.6  19.4     20.5     20.1      20.0
# 19  Louisiana          100%     19.4  18.8     19.8     19.6      19.5
# 20      Maine            8%     24.2  24.0     24.8     23.7      24.3
# 21   Maryland           28%     23.3  23.1     24.2     23.8      23.6

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
# Act 2017 Data Types
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
# SAT 2017 Data Types
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# -ACT Participation and Composite dtype shows as object but should be float
#
# -SAT Participation dtype shows as object should should be float

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
act_2017.head(2)
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2

# %%
sat_2017.head(2)
# Out:
#      State Participation  Evidence-Based Reading and Writing  Math  Total
# 0  Alabama            5%                                 593   572   1165
# 1   Alaska           38%                                 547   533   1080

# %% [markdown]
# > <font size = 3 color = "crimson"> correct, but do follow the instructions in defining a function instead of using lambda</font>

# %%
#Remove '%' and replace with blank ('') using lambda function
act_2017['Participation'] = act_2017['Participation'].map(lambda state: state.replace('%',''))
sat_2017['Participation'] = sat_2017['Participation'].map(lambda state: state.replace('%',''))

# %%
#Change type to float and convert to decimal place by dividing the cells in Participation over 100
act_2017['Participation'] = act_2017['Participation'].astype(float) / 100 
sat_2017['Participation'] = sat_2017['Participation'].astype(float) / 100

# %%
# Min and Max result for Particpation rate in SAT 2017
print('Minimum Possible Value')
print(sat_2017[['Participation']].min())
print('Maximum Possible Value')
print(sat_2017[['Participation']].max())
# Out:
# Minimum Possible Value
# Participation    0.02
# dtype: float64
# Maximum Possible Value
# Participation    1.0
# dtype: float64

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
# Using np.unique to identify whats causing the column to show as object type
np.unique(act_2017['Composite'])
# Out:
# array(['17.8', '18.6', '18.7', '19.0', '19.1', '19.2', '19.4', '19.5',
#        '19.7', '19.8', '20.0', '20.2x', '20.3', '20.4', '20.5', '20.7',
#        '20.8', '21.0', '21.4', '21.5', '21.7', '21.8', '21.9', '22.0',
#        '22.3', '22.6', '22.8', '23.6', '23.7', '23.8', '23.9', '24.0',
#        '24.1', '24.2', '24.3', '25.2', '25.4', '25.5'], dtype=object)

# %%
#Remove 'x' and replace with blank ('') using lambda function
act_2017['Composite'] = act_2017['Composite'].map(lambda comp: comp.replace('x',''))

# %%
#Change type to float
act_2017['Composite']  = act_2017['Composite'].astype(float)

# %%
# Min and Max result for Particpation rate and Composite in ACT 2017
print('Minimum Possible Value')
print(act_2017[['Participation','Composite']].min())
print('Maximum Possible Value')
print(act_2017[['Participation','Composite']].max())
# Out:
# Minimum Possible Value
# Participation     0.08
# Composite        17.80
# dtype: float64
# Maximum Possible Value
# Participation     1.0
# Composite        25.5
# dtype: float64

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
# Checked column data type, ensure its float
print(act_2017['Participation'].dtypes)
print(act_2017['Composite'].dtypes)
print(sat_2017['Participation'].dtypes)
# Out:
# float64
# float64
# float64

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Display data types for all column in dataframe for ACT 2017
print(act_2017.head(2))
act_2017.dtypes
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National            0.6     20.3  20.7     21.4     21.0       21.0
# 1   Alabama            1.0     18.9  18.4     19.7     19.4       19.2
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
#Display data types for all column in dataframe for SAT 2017
print(sat_2017.head(2))
sat_2017.dtypes
# Out:
#      State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0  Alabama           0.05                                 593   572   1165
# 1   Alaska           0.38                                 547   533   1080
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
act_2017.head(0)
# Out:
# Empty DataFrame
# Columns: [State, Participation, English, Math, Reading, Science, Composite]
# Index: []

# %%
#Renaming the columns to lower case and adding act except for State using Dictionary  
#in order to differentiate between data sets columns when they are combined

new_columns_act = {
    'State': 'state',
    'Participation': 'act17_participation',
    'English': 'act17_english',
    'Math': 'act17_math',
    'Reading': 'act17_reading',
    'Science': 'act17_science',
    'Composite': 'act17_composite',   
}

act_2017.rename(columns = new_columns_act, inplace=True)
act_2017.head(2)
# Out:
#       state  act17_participation  act17_english  act17_math  act17_reading  \
# 0  National                  0.6           20.3        20.7           21.4
# 1   Alabama                  1.0           18.9        18.4           19.7
#
#    act17_science  act17_composite
# 0           21.0             21.0
# 1           19.4             19.2

# %% [markdown]
# > <font size = 3 color = "crimson"> Some tips when renaming columns. <br> 1. Keep column names short. <br> 2. Try to use .lower() instead of manually changing column names to lowercase <br> list comprehension df.columns = ['sat17_' + col.lower() for col in df.columns]<br> 3. Try to use df.add_prefix() or df.add_suffix() to add to column names<br>
# <br>def update_cols(df,prefix):<br>
#     df.columns = [x.lower().replace('evidence-based reading and writing','ebrw').replace('participation','rate')
#                   for x in df.columns] <br>
#     df.columns = [prefix + x if x !='state' else x for x in df.columns] <br>
#     return df</font>

# %%
sat_2017.head(0)
# Out:
# Empty DataFrame
# Columns: [State, Participation, Evidence-Based Reading and Writing, Math, Total]
# Index: []

# %%
#Renaming the columns to lower case and adding sat except for State using Dictionary  
#in order to differentiate between data sets when they are combined
new_columns_sat = {
    'State': 'state',
    'Participation': 'sat17_participation',
    'Evidence-Based Reading and Writing': 'sat17_read_write',
    'Math': 'sat17_math',
    'Total': 'sat17_total', 
}

sat_2017.rename(columns = new_columns_sat, inplace=True)
sat_2017.head(2)
# Out:
#      state  sat17_participation  sat17_read_write  sat17_math  sat17_total
# 0  Alabama                 0.05               593         572         1165
# 1   Alaska                 0.38               547         533         1080

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|*object*|2017 ACT/SAT|States in the USA|
# |**act17_participation**|*float*|2017 ACT|Mean Participation Rate for ACT in the respective state (units in %)|
# |**act17_english**|*float*|2017 ACT|Mean English score in the ACT|
# |**act17_math**|*float*|2017 ACT|Mean Math score in the ACT|
# |**act17_reading**|*float*|2017 ACT|Mean Reading score in the ACT|
# |**act17_science**|*float*|2017 ACT|Mean Science score in the ACT|
# |**act17_composite**|*float*|2017 ACT|Average score English, Math, Reading & Science|
# |**sat17_participation**|*float*|2017 SAT|Mean Participation Rate for SAT in the respective state (units in %)|
# |**sat17_read_write**|*int*|2017 SAT|Mean Evidence-Based Reading and Writing score in the SAT|
# |**sat17_math**|*int*|2017 SAT|Mean Math score in the SAT|
# |**sat17_total**|*int*|2017 SAT|Mean Total score of Evidence-Based Reading and Writing & Math|

# %% [markdown]
# > <font size = 3 color = "crimson"> Include the theoretical min and max range for scores under description</font>

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
# Used drop to remove the additional "National" row in ACT dataframe
act_2017.drop(index = 0, inplace = True)
act_2017.head()
# Out:
#         state  act17_participation  act17_english  act17_math  act17_reading  \
# 1     Alabama                 1.00           18.9        18.4           19.7
# 2      Alaska                 0.65           18.7        19.8           20.4
# 3     Arizona                 0.62           18.6        19.8           20.1
# 4    Arkansas                 1.00           18.9        19.0           19.7
# 5  California                 0.31           22.5        22.7           23.1
#
#    act17_science  act17_composite
# 1           19.4             19.2
# 2           19.9             19.8
# 3           19.8             19.7
# 4           19.5             19.4
# 5           22.2             22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %% [markdown]
# > <font size = 3 color = "crimson"> As the states are the same in both dataframes, the joins (inner, outer, left, right) would all produce the same result. It would be good to familiarize yourself with the different types of joins. </font>

# %%
# Use merge to combine the ACT and SAT dataframes and assigned to new variable merged_2017
merged_2017 = pd.merge(act_2017, sat_2017, on='state', how='left')
merged_2017.head()
# Out:
#         state  act17_participation  act17_english  act17_math  act17_reading  \
# 0     Alabama                 1.00           18.9        18.4           19.7
# 1      Alaska                 0.65           18.7        19.8           20.4
# 2     Arizona                 0.62           18.6        19.8           20.1
# 3    Arkansas                 1.00           18.9        19.0           19.7
# 4  California                 0.31           22.5        22.7           23.1
#
#    act17_science  act17_composite  sat17_participation  sat17_read_write  \
# 0           19.4             19.2                 0.05               593
# 1           19.9             19.8                 0.38               547
# 2           19.8             19.7                 0.30               563
# 3           19.5             19.4                 0.03               614
# 4           22.2             22.8                 0.53               531
#
#    sat17_math  sat17_total
# 0         572         1165
# 1         533         1080
# 2         553         1116
# 3         594         1208
# 4         524         1055

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#Used .to_csv to convert the merged 2017 file into csv format and saved in the path below as 
#combined_2017
merged_2017.to_csv('combined_2017.csv')
merged_2017.to_csv(r'C:\Users\Roshan\Desktop\Project\project_1\data\combined_2017.csv')

# %% [markdown]
# > <font size = 3 color = "crimson"> Try not to use absolute path when reading or saving files. If someone downloads your repository from github, he won't be able to reproduce the same outputs. </font>

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
act_2018 = pd.read_csv('../data/act_2018_updated.csv')
sat_2018 = pd.read_csv('../data/sat_2018.csv')

# %%
# Check type of ACT and SAT 2018 data to ensure its DataFrame format
print(type(act_2018))
print(type(sat_2018))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
#Print out the first 10 rows for ACT 2018 dataset to examine what it looks like
act_2018.head(10)
# Out:
#                   State  Percentage of Students Tested  \
# 0               Alabama                            100
# 1                Alaska                             33
# 2               Arizona                             66
# 3              Arkansas                            100
# 4            California                             27
# 5              Colorado                             30
# 6           Connecticut                             26
# 7              Delaware                             17
# 8  District of Columbia                             32
# 9               Florida                             66
#
#    Average Composite Score  Average English Score  Average Math Score  \
# 0                     19.1                   18.9                18.3
# 1                     20.8                   19.8                20.6
# 2                     19.2                   18.2                19.4
# 3                     19.4                   19.1                18.9
# 4                     22.7                   22.5                22.5
# 5                     23.9                   23.9                23.2
# 6                     25.6                   26.0                24.8
# 7                     23.2                   23.7                23.1
# 8                     23.6                   23.7                22.7
# 9                     19.9                   19.2                19.3
#
#    Average Reading Score  Average Science Score
# 0                   19.6                   19.0
# 1                   21.6                   20.7
# 2                   19.5                   19.2
# 3                   19.7                   19.4
# 4                   23.0                   22.1
# 5                   24.4                   23.5
# 6                   26.1                   24.9
# 7                   24.5                   23.4
# 8                   24.4                   23.0
# 9                   21.1                   19.5

# %%
#Print out the first 10 rows for SAT 2018 dataset to examine what it looks like
sat_2018.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            6%                                 595
# 1                Alaska           43%                                 562
# 2               Arizona           29%                                 577
# 3              Arkansas            5%                                 592
# 4            California           60%                                 540
# 5              Colorado          100%                                 519
# 6           Connecticut          100%                                 535
# 7              Delaware          100%                                 505
# 8  District of Columbia           92%                                 497
# 9               Florida           56%                                 550
#
#    Math  Total
# 0   571   1166
# 1   544   1106
# 2   572   1149
# 3   576   1169
# 4   536   1076
# 5   506   1025
# 6   519   1053
# 7   492    998
# 8   480    977
# 9   549   1099

# %%
# Look at the data types of the columns for both ACT and SAT 2018
# Check the non-null count to ensure no missing value
# And ensure no additional data by comparing RangeIndex of ACT and SAT 2018
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          51 non-null     object
#  1   Percentage of Students Tested  51 non-null     int64
#  2   Average Composite Score        51 non-null     float64
#  3   Average English Score          51 non-null     float64
#  4   Average Math Score             51 non-null     float64
#  5   Average Reading Score          51 non-null     float64
#  6   Average Science Score          51 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.9+ KB

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
#Change type to float and convert to decimal place by dividing the cells in Percentage Of Students Tested over 100
act_2018['Percentage of Students Tested'] = act_2018['Percentage of Students Tested'].astype(float)/100

# %%
# Use lambda function to replace '%' with '' (blank)
sat_2018['Participation'] = sat_2018['Participation'].map(lambda part: part.replace('%',''))

# %%
#Change type to float and convert to decimal place by dividing the cells in Participation over 100
sat_2018['Participation'] = sat_2018['Participation'].astype(float)/100

# %%
# Check Min and Max possible values ensuring their in the range for ACT 2018
print('Minimum Possible Value')
print(act_2018[['Percentage of Students Tested', 'Average Composite Score',
                'Average English Score', 'Average Math Score', 'Average Reading Score',	
                'Average Science Score']].min())
print('Maximum Possible Value')
print(act_2018[['Percentage of Students Tested', 'Average Composite Score',
                'Average English Score', 'Average Math Score', 'Average Reading Score',	
                'Average Science Score']].max())
# Out:
# Minimum Possible Value
# Percentage of Students Tested     0.07
# Average Composite Score          17.70
# Average English Score            16.60
# Average Math Score               17.80
# Average Reading Score            18.00
# Average Science Score            17.90
# dtype: float64
# Maximum Possible Value
# Percentage of Students Tested     1.0
# Average Composite Score          25.6
# Average English Score            26.0
# Average Math Score               25.2
# Average Reading Score            26.1
# Average Science Score            24.9
# dtype: float64

# %%
# Check Min and Max possible values ensuring their in the range for SAT 2018
print('Minimum Possible Value')
print(sat_2018[['Participation', 'Evidence-Based Reading and Writing', 'Math']].min())
print('Maximum Possible Value')
print(sat_2018[['Participation', 'Evidence-Based Reading and Writing', 'Math']].max())
# Out:
# Minimum Possible Value
# Participation                           0.02
# Evidence-Based Reading and Writing    480.00
# Math                                  480.00
# dtype: float64
# Maximum Possible Value
# Participation                           1.0
# Evidence-Based Reading and Writing    643.0
# Math                                  655.0
# dtype: float64

# %%
#Display data types for all column in dataframe for ACT 2018
print(act_2018.head(2))
act_2018.dtypes
# Out:
#      State  Percentage of Students Tested  Average Composite Score  \
# 0  Alabama                           1.00                     19.1
# 1   Alaska                           0.33                     20.8
#
#    Average English Score  Average Math Score  Average Reading Score  \
# 0                   18.9                18.3                   19.6
# 1                   19.8                20.6                   21.6
#
#    Average Science Score
# 0                   19.0
# 1                   20.7
# State                             object
# Percentage of Students Tested    float64
# Average Composite Score          float64
# Average English Score            float64
# Average Math Score               float64
# Average Reading Score            float64
# Average Science Score            float64
# dtype: object

# %%
#Check data types for all column in dataframe for ACT 2018
print(sat_2018.head(2))
sat_2018.dtypes
# Out:
#      State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0  Alabama           0.06                                 595   571   1166
# 1   Alaska           0.43                                 562   544   1106
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
# Shift Average Composite Score to the last column to standardize with ACT 2017 data set
act_2018 = act_2018[['State', 'Percentage of Students Tested', 'Average English Score',
                    'Average Math Score', 'Average Reading Score', 'Average Science Score',
                    'Average Composite Score']]

# %%
act_2018.head(1)
# Out:
#      State  Percentage of Students Tested  Average English Score  \
# 0  Alabama                            1.0                   18.9
#
#    Average Math Score  Average Reading Score  Average Science Score  \
# 0                18.3                   19.6                   19.0
#
#    Average Composite Score
# 0                     19.1

# %%
#Renaming the columns to lower case and adding act except for State using Dictionary  
#in order to differentiate between data sets columns when they are combined
new_columns_act18 = {
    'State': 'state',
    'Percentage of Students Tested': 'act18_participation',
    'Average English Score': 'act18_english',
    'Average Math Score': 'act18_math',
    'Average Reading Score': 'act18_reading',
    'Average Science Score': 'act18_science',
    'Average Composite Score': 'act18_composite',   
}

act_2018.rename(columns = new_columns_act18, inplace=True)
act_2018.head(2)
# Out:
#      state  act18_participation  act18_english  act18_math  act18_reading  \
# 0  Alabama                 1.00           18.9        18.3           19.6
# 1   Alaska                 0.33           19.8        20.6           21.6
#
#    act18_science  act18_composite
# 0           19.0             19.1
# 1           20.7             20.8

# %%
#Renaming the columns to lower case and adding act except for State using Dictionary  
#in order to differentiate between data sets columns when they are combined
new_columns_sat18 = {
    'State': 'state',
    'Participation': 'sat18_participation',
    'Evidence-Based Reading and Writing': 'sat18_read_write',
    'Math': 'sat18_math',
    'Total': 'sat18_total', 
}

sat_2018.rename(columns = new_columns_sat18, inplace=True)
sat_2018.head(2)
# Out:
#      state  sat18_participation  sat18_read_write  sat18_math  sat18_total
# 0  Alabama                 0.06               595         571         1166
# 1   Alaska                 0.43               562         544         1106

# %% [markdown]
# Set up the data dictionary for 2018 to provide overview of features,data types, data sets and descriptions.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|*object*|2018 ACT/SAT|States in the USA|
# |**act18_participation**|*float*|2018 ACT|Mean Participation Rate for ACT in the respective state (units in %)|
# |**act18_english**|*float*|2018 ACT|Mean English score in the ACT|
# |**act18_math**|*float*|2018 ACT|Mean Math score in the ACT|
# |**act18_reading**|*float*|2018 ACT|Mean Reading score in the ACT|
# |**act18_science**|*float*|2018 ACT|Mean Science score in the ACT|
# |**act18_composite**|*float*|2018 ACT|Average score English, Math, Reading & Science|
# |**sat18_participation**|*float*|2018 SAT|Mean Participation Rate for SAT in the respective state (units in %)|
# |**sat18_read_write**|*int*|2018 SAT|Mean Evidence-Based Reading and Writing score in the SAT|
# |**sat18_math**|*int*|2018 SAT|Mean Math score in the SAT|
# |**sat18_total**|*int*|2018 SAT|Mean Total score of Evidence-Based Reading and Writing & Math|

# %% [markdown]
# > <font size = 3 color = "crimson"> include the theoretical min, max range for the scores </font>

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
# Merge ACT 2018 and SAT 2018 data frame together using state as key and rename to merged_2018
merged_2018 = pd.merge(act_2018, sat_2018, on='state', how='left')
merged_2018.head()
# Out:
#         state  act18_participation  act18_english  act18_math  act18_reading  \
# 0     Alabama                 1.00           18.9        18.3           19.6
# 1      Alaska                 0.33           19.8        20.6           21.6
# 2     Arizona                 0.66           18.2        19.4           19.5
# 3    Arkansas                 1.00           19.1        18.9           19.7
# 4  California                 0.27           22.5        22.5           23.0
#
#    act18_science  act18_composite  sat18_participation  sat18_read_write  \
# 0           19.0             19.1                 0.06               595
# 1           20.7             20.8                 0.43               562
# 2           19.2             19.2                 0.29               577
# 3           19.4             19.4                 0.05               592
# 4           22.1             22.7                 0.60               540
#
#    sat18_math  sat18_total
# 0         571         1166
# 1         544         1106
# 2         572         1149
# 3         576         1169
# 4         536         1076

# %%
#Combine Merged_2017 and Merged_2018 data frame using state as key and rename to final_data
final_data = pd.merge(merged_2017, merged_2018, on='state', how='left')
final_data.head()
# Out:
#         state  act17_participation  act17_english  act17_math  act17_reading  \
# 0     Alabama                 1.00           18.9        18.4           19.7
# 1      Alaska                 0.65           18.7        19.8           20.4
# 2     Arizona                 0.62           18.6        19.8           20.1
# 3    Arkansas                 1.00           18.9        19.0           19.7
# 4  California                 0.31           22.5        22.7           23.1
#
#    act17_science  act17_composite  sat17_participation  sat17_read_write  \
# 0           19.4             19.2                 0.05               593
# 1           19.9             19.8                 0.38               547
# 2           19.8             19.7                 0.30               563
# 3           19.5             19.4                 0.03               614
# 4           22.2             22.8                 0.53               531
#
#    sat17_math  ...  act18_participation  act18_english  act18_math  \
# 0         572  ...                 1.00           18.9        18.3
# 1         533  ...                 0.33           19.8        20.6
# 2         553  ...                 0.66           18.2        19.4
# 3         594  ...                 1.00           19.1        18.9
# 4         524  ...                 0.27           22.5        22.5
#
#    act18_reading  act18_science  act18_composite  sat18_participation  \
# 0           19.6           19.0             19.1                 0.06
# 1           21.6           20.7             20.8                 0.43
# 2           19.5           19.2             19.2                 0.29
# 3           19.7           19.4             19.4                 0.05
# 4           23.0           22.1             22.7                 0.60
#
#    sat18_read_write  sat18_math  sat18_total
# 0               595         571         1166
# 1               562         544         1106
# 2               577         572         1149
# 3               592         576         1169
# 4               540         536         1076
#
# [5 rows x 21 columns]

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state                51 non-null     object
#  1   act17_participation  51 non-null     float64
#  2   act17_english        51 non-null     float64
#  3   act17_math           51 non-null     float64
#  4   act17_reading        51 non-null     float64
#  5   act17_science        51 non-null     float64
#  6   act17_composite      51 non-null     float64
#  7   sat17_participation  51 non-null     float64
#  8   sat17_read_write     51 non-null     int64
#  9   sat17_math           51 non-null     int64
#  10  sat17_total          51 non-null     int64
#  11  act18_participation  51 non-null     float64
#  12  act18_english        51 non-null     float64
#  13  act18_math           51 non-null     float64
#  14  act18_reading        51 non-null     float64
#  15  act18_science        51 non-null     float64
#  16  act18_composite      51 non-null     float64
#  17  sat18_participation  51 non-null     float64
#  18  sat18_read_write     51 non-null     int64
#  19  sat18_math           51 non-null     int64
#  20  sat18_total          51 non-null     int64
# dtypes: float64(14), int64(6), object(1)
# memory usage: 8.8+ KB

# %%
final_data.to_csv('final.csv')
final_data.to_csv(r'C:\Users\Roshan\Desktop\Project\project_1\data\final.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
final_data.describe().T
# Out:
#                      count         mean        std     min       25%      50%  \
# act17_participation   51.0     0.652549   0.321408    0.08     0.310     0.69
# act17_english         51.0    20.931373   2.353677   16.30    19.000    20.70
# act17_math            51.0    21.182353   1.981989   18.00    19.400    20.90
# act17_reading         51.0    22.013725   2.067271   18.10    20.450    21.80
# act17_science         51.0    21.462745   1.753392   18.20    19.950    21.30
# act17_composite       51.0    21.519608   2.020695   17.80    19.800    21.40
# sat17_participation   51.0     0.398039   0.352766    0.02     0.040     0.38
# sat17_read_write      51.0   569.117647  45.666901  482.00   533.500   559.00
# sat17_math            51.0   556.882353  47.121395  468.00   523.500   548.00
# sat17_total           51.0  1126.098039  92.494812  950.00  1055.500  1107.00
# act18_participation   51.0     0.616471   0.340810    0.07     0.285     0.66
# act18_english         51.0    20.988235   2.446356   16.60    19.100    20.20
# act18_math            51.0    21.125490   2.035765   17.80    19.400    20.70
# act18_reading         51.0    22.015686   2.167245   18.00    20.450    21.60
# act18_science         51.0    21.345098   1.870114   17.90    19.850    21.10
# act18_composite       51.0    21.486275   2.106278   17.70    19.950    21.30
# sat18_participation   51.0     0.457451   0.373143    0.02     0.045     0.52
# sat18_read_write      51.0   563.686275  47.502627  480.00   534.500   552.00
# sat18_math            51.0   556.235294  47.772623  480.00   522.500   544.00
# sat18_total           51.0  1120.019608  94.155083  977.00  1057.500  1098.00
#
#                           75%     max
# act17_participation     1.000     1.0
# act17_english          23.300    25.5
# act17_math             23.100    25.3
# act17_reading          24.150    26.0
# act17_science          23.200    24.9
# act17_composite        23.600    25.5
# sat17_participation     0.660     1.0
# sat17_read_write      613.000   644.0
# sat17_math            599.000   651.0
# sat17_total          1212.000  1295.0
# act18_participation     1.000     1.0
# act18_english          23.700    26.0
# act18_math             23.150    25.2
# act18_reading          24.100    26.1
# act18_science          23.050    24.9
# act18_composite        23.550    25.6
# sat18_participation     0.775     1.0
# sat18_read_write      610.500   643.0
# sat18_math            593.500   655.0
# sat18_total          1204.000  1298.0

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
import math

# %% [markdown]
# > <font size = 3 color = "crimson"> As good practice, try to import all libraries in the same cell at the start of the notebook</font>

# %%
#Mean Function
def mean(x):
    return sum(x)*1.0/len(x) # Sum times 1.0 so it would have decimal place
#Standard Deviation Function
def stanDev(x):
    len_value = len(x) # Number of Data Points
    avg_value = mean(x)
    total = 0
    for i in range(len_value): 
        total += (x[i]-avg_value)**2 #Sum the square of the diff between the data point and mean
    sqr_root = total*1.0/len_value # Divide by number of data point to get avg square diff
    return math.sqrt(sqr_root) # Used math.sqrt to square root avg square diff

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Use a dictionary comprehension to apply your standard deviation function to each numeric column
sd = {x:stanDev(final_data[x]) for x in final_data.columns[1:]}
sd
# Out:
# {'act17_participation': 0.3182417575123181,
#  'act17_english': 2.3304876369363363,
#  'act17_math': 1.9624620273436781,
#  'act17_reading': 2.0469029314842646,
#  'act17_science': 1.7361170088327353,
#  'act17_composite': 2.000786081581989,
#  'sat17_participation': 0.3492907076664507,
#  'sat17_read_write': 45.21697020437866,
#  'sat17_math': 46.65713364485503,
#  'sat17_total': 91.58351056778743,
#  'act18_participation': 0.33745194881997503,
#  'act18_english': 2.4222536143202795,
#  'act18_math': 2.015707255555717,
#  'act18_reading': 2.145891884510421,
#  'act18_science': 1.8516885484833543,
#  'act18_composite': 2.0855261815801147,
#  'sat18_participation': 0.3694661922353942,
#  'sat18_read_write': 47.03460978357609,
#  'sat18_math': 47.30194550378352,
#  'sat18_total': 93.22742384464433}

# %% [markdown]
# > <font size = 3 color = "crimson"> Good work. Do round off the numbers</font>

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Notice the manually calculated standard deviation of the columns above does not match with the output
# from pandas describe, however the figures does match with numpy's std method.

# %% [markdown]
# > <font size = 3 color = "crimson"> The difference is due to Bessel's correction being applied in std calculations for pandas. https://www.statisticshowto.datasciencecentral.com/bessels-correction/</font>

# %%
# Using pandas .describe method
final_data.describe()
# Out:
#        act17_participation  act17_english  act17_math  act17_reading  \
# count            51.000000      51.000000   51.000000      51.000000
# mean              0.652549      20.931373   21.182353      22.013725
# std               0.321408       2.353677    1.981989       2.067271
# min               0.080000      16.300000   18.000000      18.100000
# 25%               0.310000      19.000000   19.400000      20.450000
# 50%               0.690000      20.700000   20.900000      21.800000
# 75%               1.000000      23.300000   23.100000      24.150000
# max               1.000000      25.500000   25.300000      26.000000
#
#        act17_science  act17_composite  sat17_participation  sat17_read_write  \
# count      51.000000        51.000000            51.000000         51.000000
# mean       21.462745        21.519608             0.398039        569.117647
# std         1.753392         2.020695             0.352766         45.666901
# min        18.200000        17.800000             0.020000        482.000000
# 25%        19.950000        19.800000             0.040000        533.500000
# 50%        21.300000        21.400000             0.380000        559.000000
# 75%        23.200000        23.600000             0.660000        613.000000
# max        24.900000        25.500000             1.000000        644.000000
#
#        sat17_math  sat17_total  act18_participation  act18_english  \
# count   51.000000    51.000000            51.000000      51.000000
# mean   556.882353  1126.098039             0.616471      20.988235
# std     47.121395    92.494812             0.340810       2.446356
# min    468.000000   950.000000             0.070000      16.600000
# 25%    523.500000  1055.500000             0.285000      19.100000
# 50%    548.000000  1107.000000             0.660000      20.200000
# 75%    599.000000  1212.000000             1.000000      23.700000
# max    651.000000  1295.000000             1.000000      26.000000
#
#        act18_math  act18_reading  act18_science  act18_composite  \
# count   51.000000      51.000000      51.000000        51.000000
# mean    21.125490      22.015686      21.345098        21.486275
# std      2.035765       2.167245       1.870114         2.106278
# min     17.800000      18.000000      17.900000        17.700000
# 25%     19.400000      20.450000      19.850000        19.950000
# 50%     20.700000      21.600000      21.100000        21.300000
# 75%     23.150000      24.100000      23.050000        23.550000
# max     25.200000      26.100000      24.900000        25.600000
#
#        sat18_participation  sat18_read_write  sat18_math  sat18_total
# count            51.000000         51.000000   51.000000    51.000000
# mean              0.457451        563.686275  556.235294  1120.019608
# std               0.373143         47.502627   47.772623    94.155083
# min               0.020000        480.000000  480.000000   977.000000
# 25%               0.045000        534.500000  522.500000  1057.500000
# 50%               0.520000        552.000000  544.000000  1098.000000
# 75%               0.775000        610.500000  593.500000  1204.000000
# max               1.000000        643.000000  655.000000  1298.000000

# %%
# Using Numpy std method
np.std(final_data)
# Out:
# act17_participation     0.318242
# act17_english           2.330488
# act17_math              1.962462
# act17_reading           2.046903
# act17_science           1.736117
# act17_composite         2.000786
# sat17_participation     0.349291
# sat17_read_write       45.216970
# sat17_math             46.657134
# sat17_total            91.583511
# act18_participation     0.337452
# act18_english           2.422254
# act18_math              2.015707
# act18_reading           2.145892
# act18_science           1.851689
# act18_composite         2.085526
# sat18_participation     0.369466
# sat18_read_write       47.034610
# sat18_math             47.301946
# sat18_total            93.227424
# dtype: float64

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Sort by State with the Highest participation rate - SAT 2017
sat_high17 = final_data.loc[:,['state', 'sat17_participation']]
sat_high17.groupby('state').sum().sort_values('sat17_participation', ascending=False).head()
# Out:
#                       sat17_participation
# state
# District of Columbia                 1.00
# Michigan                             1.00
# Connecticut                          1.00
# Delaware                             1.00
# New Hampshire                        0.96

# %% [markdown]
# > <font size = 3 color = "crimson"> There is no need to include groupby in your code as no aggregation is required. <br>
# final_data[['state','sat17_participation']].sort_values('sat17_participation',ascending = False)</font>

# %%
#Sort by State with the Lowest participation rate - SAT 2017
sat_low17 = final_data.loc[:,['state', 'sat17_participation']]
sat_low17.groupby('state').sum().sort_values('sat17_participation', ascending=True).head()
# Out:
#               sat17_participation
# state
# North Dakota                 0.02
# Mississippi                  0.02
# Iowa                         0.02
# Missouri                     0.03
# Utah                         0.03

# %%
#Sort by State with the Highest participation rate - SAT 2018
sat_high18 = final_data.loc[:,['state', 'sat18_participation']]
sat_high18.groupby('state').sum().sort_values('sat18_participation', ascending=False).head(6)
# Out:
#              sat18_participation
# state
# Colorado                    1.00
# Connecticut                 1.00
# Delaware                    1.00
# Michigan                    1.00
# Idaho                       1.00
# Maine                       0.99

# %%
#Sort by State with the lowest participation rate - SAT 2018
sat_low18 = final_data.loc[:,['state', 'sat18_participation']]
sat_low18.groupby('state').sum().sort_values('sat18_participation', ascending=True).head()
# Out:
#               sat18_participation
# state
# North Dakota                 0.02
# Wyoming                      0.03
# South Dakota                 0.03
# Nebraska                     0.03
# Wisconsin                    0.03

# %%
#Sort by State with the Highest participation rate - ACT 2017
act_high17 = final_data.loc[:,['state', 'act17_participation']]
act_high17.groupby('state').sum().sort_values('act17_participation', ascending=False).head(10)
# Out:
#                 act17_participation
# state
# Alabama                         1.0
# Kentucky                        1.0
# Wisconsin                       1.0
# Utah                            1.0
# Tennessee                       1.0
# South Carolina                  1.0
# Oklahoma                        1.0
# North Carolina                  1.0
# Nevada                          1.0
# Montana                         1.0

# %% [markdown]
# > <font size = 3 color = "crimson"> Do adjust the number of rows. In this case, there are 17 states with 100% participation </font>

# %%
#Sort by State with the Lowest participation rate - ACT 2017
act_low17 = final_data.loc[:,['state', 'act17_participation']]
act_low17.groupby('state').sum().sort_values('act17_participation', ascending=True).head()
# Out:
#                act17_participation
# state
# Maine                         0.08
# New Hampshire                 0.18
# Delaware                      0.18
# Rhode Island                  0.21
# Pennsylvania                  0.23

# %%
#Sort by State with the Highest participation rate - ACT 2018
act_high18 = final_data.loc[:,['state', 'act18_participation']]
act_high18.groupby('state').sum().sort_values('act18_participation', ascending=False).head()
# Out:
#            act18_participation
# state
# Alabama                    1.0
# Kentucky                   1.0
# Wisconsin                  1.0
# Utah                       1.0
# Tennessee                  1.0

# %%
#Sort by State with the Highest participation rate - ACT 2018
act_low18 = final_data.loc[:,['state', 'act18_participation']]
act_low18.groupby('state').sum().sort_values('act18_participation', ascending=True).head()
# Out:
#                act18_participation
# state
# Maine                         0.07
# Rhode Island                  0.15
# New Hampshire                 0.16
# Delaware                      0.17
# Pennsylvania                  0.20

# %%
#Sort by State with the Highest Total Score - SAT 2017
sat2_high17 = final_data.loc[:,['state', 'sat17_total']]
sat2_high17.groupby('state').sum().sort_values('sat17_total', ascending=False).head()
# Out:
#            sat17_total
# state
# Minnesota         1295
# Wisconsin         1291
# Iowa              1275
# Missouri          1271
# Kansas            1260

# %%
#Sort by State with the Lowest Total Score - SAT 2017
sat2_low17 = final_data.loc[:,['state', 'sat17_total']]
sat2_low17.groupby('state').sum().sort_values('sat17_total', ascending=True).head()
# Out:
#                       sat17_total
# state
# District of Columbia          950
# Delaware                      996
# Idaho                        1005
# Michigan                     1005
# Maine                        1012

# %%
#Sort by State with the Highest Total Score - SAT 2018
sat2_high18 = final_data.loc[:,['state', 'sat18_total']]
sat2_high18.groupby('state').sum().sort_values('sat18_total', ascending=False).head()
# Out:
#               sat18_total
# state
# Minnesota            1298
# Wisconsin            1294
# North Dakota         1283
# Iowa                 1265
# Kansas               1265

# %%
#Sort by State with the Lowest Total Score - SAT 2018
sat2_low18 = final_data.loc[:,['state', 'sat18_total']]
sat2_low18.groupby('state').sum().sort_values('sat18_total', ascending=True).head()
# Out:
#                       sat18_total
# state
# District of Columbia          977
# Delaware                      998
# West Virginia                 999
# Idaho                        1001
# Utah                         1010

# %%
#Sort by State with the Highest Composite Score - ACT 2017
act2_high17 = final_data.loc[:,['state', 'act17_composite']]
act2_high17.groupby('state').sum().sort_values('act17_composite', ascending=False).head()
# Out:
#                       act17_composite
# state
# New Hampshire                    25.5
# Massachusetts                    25.4
# Connecticut                      25.2
# Maine                            24.3
# District of Columbia             24.2

# %%
#Sort by State with the Lowest Composite Score - ACT 2017
act2_low17 = final_data.loc[:,['state', 'act17_composite']]
act2_low17.groupby('state').sum().sort_values('act17_composite', ascending=True).head()
# Out:
#                 act17_composite
# state
# Nevada                     17.8
# Mississippi                18.6
# South Carolina             18.7
# Hawaii                     19.0
# North Carolina             19.1

# %%
#Sort by State with the Highest Composite Score - ACT 2018
act2_high18 = final_data.loc[:,['state', 'act18_composite']]
act2_high18.groupby('state').sum().sort_values('act18_composite', ascending=False).head()
# Out:
#                act18_composite
# state
# Connecticut               25.6
# Massachusetts             25.5
# New Hampshire             25.1
# New York                  24.5
# Michigan                  24.4

# %%
#Sort by State with the Lowest Composite Score - ACT 2018
act2_low18 = final_data.loc[:,['state', 'act18_composite']]
act2_low18.groupby('state').sum().sort_values('act18_composite', ascending=True).head()
# Out:
#                 act18_composite
# state
# Nevada                     17.7
# South Carolina             18.3
# Mississippi                18.6
# Hawaii                     18.9
# Alabama                    19.1

# %%
#States with 100% participation year over year for SAT
sat_score = final_data.loc[:,['state', 'sat17_participation', 'sat18_participation']]
sat_score1 = sat_score[(sat_score['sat17_participation'] == 1.0) & 
          (sat_score['sat18_participation'] == 1.0)]
sat_score1
# Out:
#           state  sat17_participation  sat18_participation
# 6   Connecticut                  1.0                  1.0
# 7      Delaware                  1.0                  1.0
# 22     Michigan                  1.0                  1.0

# %%
#States with 100% participation year over year for ACT
act_score1 = final_data.loc[:,['state', 'act17_participation', 'act18_participation']]
act_score2 = act_score1[(act_score1['act17_participation'] == 1.0) & 
                     (act_score1['act18_participation'] == 1.0)]
act_score2
# Out:
#              state  act17_participation  act18_participation
# 0          Alabama                  1.0                  1.0
# 3         Arkansas                  1.0                  1.0
# 17        Kentucky                  1.0                  1.0
# 18       Louisiana                  1.0                  1.0
# 24     Mississippi                  1.0                  1.0
# 25        Missouri                  1.0                  1.0
# 26         Montana                  1.0                  1.0
# 28          Nevada                  1.0                  1.0
# 33  North Carolina                  1.0                  1.0
# 36        Oklahoma                  1.0                  1.0
# 40  South Carolina                  1.0                  1.0
# 42       Tennessee                  1.0                  1.0
# 44            Utah                  1.0                  1.0
# 49       Wisconsin                  1.0                  1.0
# 50         Wyoming                  1.0                  1.0

# %%
# States that had a 100% participation rate for SAT in 2017 but decline in 2018
# Create a column to see the difference
final_data['sat_diff'] = final_data['sat17_participation'] - final_data['sat18_participation']
sat_score3 = final_data.loc[:,['state', 'sat17_participation', 'sat18_participation', 'sat_diff']]
sat_score3[(sat_score3['sat17_participation'] == 1.0) & (sat_score3['sat_diff'] != 0)]
# Out:
#                   state  sat17_participation  sat18_participation  sat_diff
# 8  District of Columbia                  1.0                 0.92      0.08

# %%
# States that had a 100% participation rate for ACT in 2017 but decline in 2018
# Create a column to see the difference
final_data['act_diff'] = final_data['act17_participation'] - final_data['act18_participation']
act_score3 = final_data.loc[:,['state', 'act17_participation', 'act18_participation', 'act_diff']]
act_score3[(act_score3['act17_participation'] == 1.0) & (act_score3['act_diff'] != 0)]
# Out:
#         state  act17_participation  act18_participation  act_diff
# 5    Colorado                  1.0                 0.30      0.70
# 23  Minnesota                  1.0                 0.99      0.01

# %%
# States that had increase to 100% participation rate for SAT in 2018 from 2017
sat_score3[(sat_score3['sat18_participation'] == 1.0) & (sat_score3['sat_diff'] != 0)]
# Out:
#        state  sat17_participation  sat18_participation  sat_diff
# 5   Colorado                 0.11                  1.0     -0.89
# 12     Idaho                 0.93                  1.0     -0.07

# %%
# States that had increase to 100% participation rate for ACT in 2018 from 2017
act_score3[(act_score3['act18_participation'] == 1.0) & (act_score3['act_diff'] != 0)]
# Out:
#        state  act17_participation  act18_participation  act_diff
# 27  Nebraska                 0.84                  1.0     -0.16
# 35      Ohio                 0.75                  1.0     -0.25

# %%
#States with participation greater than 50% for both SAT and ACT in 2017
sat_high17 = final_data.loc[:,['state', 'sat17_participation', 'act17_participation']]
sat_high17[(sat_high17['sat17_participation'] > 0.5) & 
                     (sat_high17['act17_participation'] > 0.5)]
# Out:
#       state  sat17_participation  act17_participation
# 9   Florida                 0.83                 0.73
# 10  Georgia                 0.61                 0.55
# 11   Hawaii                 0.55                 0.90

# %%
#States with participation greater than 50% for both SAT and ACT in 2018
sat_high18 = final_data.loc[:,['state', 'sat18_participation', 'act18_participation']]
sat_high18[(sat_high18['sat18_participation'] > 0.5) & 
                     (sat_high18['act18_participation'] > 0.5)]
# Out:
#              state  sat18_participation  act18_participation
# 9          Florida                 0.56                 0.66
# 10         Georgia                 0.70                 0.53
# 11          Hawaii                 0.56                 0.89
# 33  North Carolina                 0.52                 1.00
# 40  South Carolina                 0.55                 1.00

# %%
# Monitoring SAT Particapation movement from 2017 to 2018
diff_sat_highest = final_data.loc[:,['state', 'sat17_participation', 'sat18_participation', 'sat17_total', 'sat18_total', 'sat_diff']]
diff_sat_highest.sort_values("sat_diff", ascending = False)
# Out:
#                    state  sat17_participation  sat18_participation  \
# 9                Florida                 0.83                 0.56
# 8   District of Columbia                 1.00                 0.92
# 28                Nevada                 0.26                 0.23
# 2                Arizona                 0.30                 0.29
# 50               Wyoming                 0.03                 0.03
# 29         New Hampshire                 0.96                 0.96
# 18             Louisiana                 0.04                 0.04
# 17              Kentucky                 0.04                 0.04
# 16                Kansas                 0.04                 0.04
# 27              Nebraska                 0.03                 0.03
# 14               Indiana                 0.63                 0.63
# 26               Montana                 0.10                 0.10
# 34          North Dakota                 0.02                 0.02
# 22              Michigan                 1.00                 1.00
# 7               Delaware                 1.00                 1.00
# 6            Connecticut                 1.00                 1.00
# 41          South Dakota                 0.03                 0.03
# 49             Wisconsin                 0.03                 0.03
# 42             Tennessee                 0.05                 0.06
# 36              Oklahoma                 0.07                 0.08
# 0                Alabama                 0.05                 0.06
# 24           Mississippi                 0.02                 0.03
# 15                  Iowa                 0.02                 0.03
# 25              Missouri                 0.03                 0.04
# 23             Minnesota                 0.03                 0.04
# 44                  Utah                 0.03                 0.04
# 11                Hawaii                 0.55                 0.56
# 3               Arkansas                 0.03                 0.05
# 33        North Carolina                 0.49                 0.52
# 46              Virginia                 0.65                 0.68
# 45               Vermont                 0.60                 0.64
# 43                 Texas                 0.62                 0.66
# 21         Massachusetts                 0.76                 0.80
# 19                 Maine                 0.95                 0.99
# 38          Pennsylvania                 0.65                 0.70
# 47            Washington                 0.64                 0.69
# 37                Oregon                 0.43                 0.48
# 1                 Alaska                 0.38                 0.43
# 31            New Mexico                 0.11                 0.16
# 40        South Carolina                 0.50                 0.55
# 35                  Ohio                 0.12                 0.18
# 4             California                 0.53                 0.60
# 12                 Idaho                 0.93                 1.00
# 20              Maryland                 0.69                 0.76
# 10               Georgia                 0.61                 0.70
# 30            New Jersey                 0.70                 0.82
# 32              New York                 0.67                 0.79
# 48         West Virginia                 0.14                 0.28
# 39          Rhode Island                 0.71                 0.97
# 5               Colorado                 0.11                 1.00
# 13              Illinois                 0.09                 0.99
#
#     sat17_total  sat18_total  sat_diff
# 9          1017         1099      0.27
# 8           950          977      0.08
# 28         1116         1140      0.03
# 2          1116         1149      0.01
# 50         1230         1257      0.00
# 29         1052         1063      0.00
# 18         1198         1210      0.00
# 17         1247         1248      0.00
# 16         1260         1265      0.00
# 27         1253         1252      0.00
# 14         1074         1074      0.00
# 26         1196         1198      0.00
# 34         1256         1283      0.00
# 22         1005         1011      0.00
# 7           996          998      0.00
# 6          1041         1053      0.00
# 41         1216         1240      0.00
# 49         1291         1294      0.00
# 42         1228         1231     -0.01
# 36         1047         1062     -0.01
# 0          1165         1166     -0.01
# 24         1242         1236     -0.01
# 15         1275         1265     -0.01
# 25         1271         1262     -0.01
# 23         1295         1298     -0.01
# 44         1238         1010     -0.01
# 11         1085         1010     -0.01
# 3          1208         1169     -0.02
# 33         1081         1098     -0.03
# 46         1102         1117     -0.03
# 45         1114         1120     -0.04
# 43         1020         1032     -0.04
# 21         1107         1125     -0.04
# 19         1012         1013     -0.04
# 38         1071         1086     -0.05
# 47         1075         1081     -0.05
# 37         1108         1117     -0.05
# 1          1080         1106     -0.05
# 31         1138         1093     -0.05
# 40         1064         1070     -0.05
# 35         1149         1099     -0.06
# 4          1055         1076     -0.07
# 12         1005         1001     -0.07
# 20         1060         1080     -0.07
# 10         1050         1064     -0.09
# 30         1056         1094     -0.12
# 32         1052         1068     -0.12
# 48         1086          999     -0.14
# 39         1062         1018     -0.26
# 5          1201         1025     -0.89
# 13         1115         1019     -0.90

# %%
diff_act_highest = final_data.loc[:,['state', 'act17_participation', 'act18_participation', 'act17_composite', 'act18_composite', 'act_diff']]
diff_act_highest.sort_values("act_diff", ascending = False)
# Out:
#                    state  act17_participation  act18_participation  \
# 5               Colorado                 1.00                 0.30
# 13              Illinois                 0.93                 0.43
# 1                 Alaska                 0.65                 0.33
# 22              Michigan                 0.29                 0.22
# 9                Florida                 0.73                 0.66
# 39          Rhode Island                 0.21                 0.15
# 47            Washington                 0.29                 0.24
# 46              Virginia                 0.29                 0.24
# 45               Vermont                 0.29                 0.24
# 6            Connecticut                 0.31                 0.26
# 43                 Texas                 0.45                 0.41
# 32              New York                 0.31                 0.27
# 21         Massachusetts                 0.29                 0.25
# 4             California                 0.31                 0.27
# 48         West Virginia                 0.69                 0.65
# 30            New Jersey                 0.34                 0.31
# 41          South Dakota                 0.80                 0.77
# 38          Pennsylvania                 0.23                 0.20
# 14               Indiana                 0.35                 0.32
# 10               Georgia                 0.55                 0.53
# 16                Kansas                 0.73                 0.71
# 12                 Idaho                 0.38                 0.36
# 29         New Hampshire                 0.18                 0.16
# 23             Minnesota                 1.00                 0.99
# 11                Hawaii                 0.90                 0.89
# 19                 Maine                 0.08                 0.07
# 7               Delaware                 0.18                 0.17
# 0                Alabama                 1.00                 1.00
# 40        South Carolina                 1.00                 1.00
# 42             Tennessee                 1.00                 1.00
# 44                  Utah                 1.00                 1.00
# 34          North Dakota                 0.98                 0.98
# 49             Wisconsin                 1.00                 1.00
# 36              Oklahoma                 1.00                 1.00
# 25              Missouri                 1.00                 1.00
# 33        North Carolina                 1.00                 1.00
# 28                Nevada                 1.00                 1.00
# 26               Montana                 1.00                 1.00
# 24           Mississippi                 1.00                 1.00
# 18             Louisiana                 1.00                 1.00
# 17              Kentucky                 1.00                 1.00
# 8   District of Columbia                 0.32                 0.32
# 3               Arkansas                 1.00                 1.00
# 50               Wyoming                 1.00                 1.00
# 31            New Mexico                 0.66                 0.67
# 15                  Iowa                 0.67                 0.68
# 37                Oregon                 0.40                 0.42
# 20              Maryland                 0.28                 0.31
# 2                Arizona                 0.62                 0.66
# 27              Nebraska                 0.84                 1.00
# 35                  Ohio                 0.75                 1.00
#
#     act17_composite  act18_composite  act_diff
# 5              20.8             23.9      0.70
# 13             21.4             23.9      0.50
# 1              19.8             20.8      0.32
# 22             24.1             24.4      0.07
# 9              19.8             19.9      0.07
# 39             24.0             24.2      0.06
# 47             21.9             22.2      0.05
# 46             23.8             23.9      0.05
# 45             23.6             24.1      0.05
# 6              25.2             25.6      0.05
# 43             20.7             20.6      0.04
# 32             24.2             24.5      0.04
# 21             25.4             25.5      0.04
# 4              22.8             22.7      0.04
# 48             20.4             20.3      0.04
# 30             23.9             23.7      0.03
# 41             21.8             21.9      0.03
# 38             23.7             23.5      0.03
# 14             22.6             22.5      0.03
# 10             21.4             21.4      0.02
# 16             21.7             21.6      0.02
# 12             22.3             22.3      0.02
# 29             25.5             25.1      0.02
# 23             21.5             21.3      0.01
# 11             19.0             18.9      0.01
# 19             24.3             24.0      0.01
# 7              24.1             23.2      0.01
# 0              19.2             19.1      0.00
# 40             18.7             18.3      0.00
# 42             19.8             19.6      0.00
# 44             20.3             20.4      0.00
# 34             20.3             20.3      0.00
# 49             20.5             20.5      0.00
# 36             19.4             19.3      0.00
# 25             20.4             20.0      0.00
# 33             19.1             19.1      0.00
# 28             17.8             17.7      0.00
# 26             20.3             20.0      0.00
# 24             18.6             18.6      0.00
# 18             19.5             19.2      0.00
# 17             20.0             20.2      0.00
# 8              24.2             23.6      0.00
# 3              19.4             19.4      0.00
# 50             20.2             20.0      0.00
# 31             19.7             19.4     -0.01
# 15             21.9             21.8     -0.01
# 37             21.8             21.3     -0.02
# 20             23.6             22.5     -0.03
# 2              19.7             19.2     -0.04
# 27             21.4             20.1     -0.16
# 35             22.0             20.3     -0.25

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %%
plt.style.use('fivethirtyeight')
# %matplotlib inline

# Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
final_data.corr()
# Out:
#                      act17_participation  act17_english  act17_math  \
# act17_participation             1.000000      -0.843501   -0.861114
# act17_english                  -0.843501       1.000000    0.967803
# act17_math                     -0.861114       0.967803    1.000000
# act17_reading                  -0.866620       0.985999    0.979630
# act17_science                  -0.837830       0.979082    0.985648
# act17_composite                -0.858134       0.990856    0.990451
# sat17_participation            -0.841234       0.686889    0.710697
# sat17_read_write                0.716153      -0.461345   -0.486126
# sat17_math                      0.682572      -0.420673   -0.420456
# sat17_total                     0.701477      -0.441947   -0.454116
# act18_participation             0.919171      -0.796637   -0.813410
# act18_english                  -0.763176       0.937173    0.910684
# act18_math                     -0.782878       0.918868    0.948795
# act18_reading                  -0.789497       0.930897    0.924997
# act18_science                  -0.763334       0.922873    0.930087
# act18_composite                -0.775514       0.932535    0.933247
# sat18_participation            -0.756479       0.679643    0.696294
# sat18_read_write                0.522593      -0.347978   -0.355133
# sat18_math                      0.555406      -0.365787   -0.340094
# sat18_total                     0.545179      -0.361303   -0.351847
# sat_diff                       -0.079274      -0.061803   -0.049840
# act_diff                        0.060575       0.002924    0.003337
#
#                      act17_reading  act17_science  act17_composite  \
# act17_participation      -0.866620      -0.837830        -0.858134
# act17_english             0.985999       0.979082         0.990856
# act17_math                0.979630       0.985648         0.990451
# act17_reading             1.000000       0.987361         0.995069
# act17_science             0.987361       1.000000         0.994207
# act17_composite           0.995069       0.994207         1.000000
# sat17_participation       0.705352       0.654100         0.694748
# sat17_read_write         -0.488441      -0.423713        -0.470382
# sat17_math               -0.442410      -0.367364        -0.417817
# sat17_total              -0.466558      -0.396291        -0.445020
# act18_participation      -0.813021      -0.784865        -0.808497
# act18_english             0.916256       0.911627         0.927275
# act18_math                0.923622       0.932000         0.938748
# act18_reading             0.937214       0.926781         0.937604
# act18_science             0.926420       0.934942         0.935847
# act18_composite           0.929711       0.930397         0.939271
# sat18_participation       0.680380       0.647999         0.683164
# sat18_read_write         -0.363354      -0.320179        -0.351602
# sat18_math               -0.374075      -0.315947        -0.354639
# sat18_total              -0.373195      -0.322012        -0.357463
# sat_diff                 -0.027661      -0.060484        -0.053821
# act_diff                 -0.010810      -0.013355        -0.001993
#
#                      sat17_participation  sat17_read_write  sat17_math  \
# act17_participation            -0.841234          0.716153    0.682572
# act17_english                   0.686889         -0.461345   -0.420673
# act17_math                      0.710697         -0.486126   -0.420456
# act17_reading                   0.705352         -0.488441   -0.442410
# act17_science                   0.654100         -0.423713   -0.367364
# act17_composite                 0.694748         -0.470382   -0.417817
# sat17_participation             1.000000         -0.874326   -0.855091
# sat17_read_write               -0.874326          1.000000    0.987056
# sat17_math                     -0.855091          0.987056    1.000000
# sat17_total                    -0.867540          0.996661    0.996822
# act18_participation            -0.792382          0.702481    0.667444
# act18_english                   0.645332         -0.447026   -0.403532
# act18_math                      0.649435         -0.450128   -0.384444
# act18_reading                   0.651892         -0.460779   -0.414636
# act18_science                   0.611675         -0.410872   -0.355104
# act18_composite                 0.639323         -0.440915   -0.388769
# sat18_participation             0.874763         -0.818925   -0.789166
# sat18_read_write               -0.666313          0.814096    0.800380
# sat18_math                     -0.686941          0.865909    0.878982
# sat18_total                    -0.684556          0.849798    0.849583
# sat_diff                        0.144239         -0.015636   -0.039272
# act_diff                       -0.002442         -0.068672   -0.060136
#
#                      sat17_total  ...  act18_math  act18_reading  \
# act17_participation     0.701477  ...   -0.782878      -0.789497
# act17_english          -0.441947  ...    0.918868       0.930897
# act17_math             -0.454116  ...    0.948795       0.924997
# act17_reading          -0.466558  ...    0.923622       0.937214
# act17_science          -0.396291  ...    0.932000       0.926781
# act17_composite        -0.445020  ...    0.938748       0.937604
# sat17_participation    -0.867540  ...    0.649435       0.651892
# sat17_read_write        0.996661  ...   -0.450128      -0.460779
# sat17_math              0.996822  ...   -0.384444      -0.414636
# sat17_total             1.000000  ...   -0.418011      -0.438811
# act18_participation     0.687107  ...   -0.856963      -0.869304
# act18_english          -0.426210  ...    0.972551       0.983390
# act18_math             -0.418011  ...    1.000000       0.979599
# act18_reading          -0.438811  ...    0.979599       1.000000
# act18_science          -0.383698  ...    0.988105       0.988227
# act18_composite        -0.415762  ...    0.990874       0.992683
# sat18_participation    -0.806796  ...    0.760668       0.755345
# sat18_read_write        0.810068  ...   -0.396155      -0.415435
# sat18_math              0.875601  ...   -0.384726      -0.427119
# sat18_total             0.852727  ...   -0.395208      -0.426412
# sat_diff               -0.027305  ...   -0.299582      -0.283968
# act_diff               -0.064783  ...    0.300703       0.316157
#
#                      act18_science  act18_composite  sat18_participation  \
# act17_participation      -0.763334        -0.775514            -0.756479
# act17_english             0.922873         0.932535             0.679643
# act17_math                0.930087         0.933247             0.696294
# act17_reading             0.926420         0.929711             0.680380
# act17_science             0.934942         0.930397             0.647999
# act17_composite           0.935847         0.939271             0.683164
# sat17_participation       0.611675         0.639323             0.874763
# sat17_read_write         -0.410872        -0.440915            -0.818925
# sat17_math               -0.355104        -0.388769            -0.789166
# sat17_total              -0.383698        -0.415762            -0.806796
# act18_participation      -0.843234        -0.858031            -0.868103
# act18_english             0.979142         0.990671             0.769916
# act18_math                0.988105         0.990874             0.760668
# act18_reading             0.988227         0.992683             0.755345
# act18_science             1.000000         0.994377             0.730759
# act18_composite           0.994377         1.000000             0.756881
# sat18_participation       0.730759         0.756881             1.000000
# sat18_read_write         -0.379754        -0.400289            -0.762055
# sat18_math               -0.379256        -0.404529            -0.791338
# sat18_total              -0.384136        -0.407387            -0.785926
# sat_diff                 -0.311403        -0.311370            -0.353309
# act_diff                  0.312620         0.321009             0.392029
#
#                      sat18_read_write  sat18_math  sat18_total  sat_diff  \
# act17_participation          0.522593    0.555406     0.545179 -0.079274
# act17_english               -0.347978   -0.365787    -0.361303 -0.061803
# act17_math                  -0.355133   -0.340094    -0.351847 -0.049840
# act17_reading               -0.363354   -0.374075    -0.373195 -0.027661
# act17_science               -0.320179   -0.315947    -0.322012 -0.060484
# act17_composite             -0.351602   -0.354639    -0.357463 -0.053821
# sat17_participation         -0.666313   -0.686941    -0.684556  0.144239
# sat17_read_write             0.814096    0.865909     0.849798 -0.015636
# sat17_math                   0.800380    0.878982     0.849583 -0.039272
# sat17_total                  0.810068    0.875601     0.852727 -0.027305
# act18_participation          0.595309    0.635613     0.622634  0.243001
# act18_english               -0.416250   -0.429791    -0.428198 -0.326388
# act18_math                  -0.396155   -0.384726    -0.395208 -0.299582
# act18_reading               -0.415435   -0.427119    -0.426412 -0.283968
# act18_science               -0.379754   -0.379256    -0.384136 -0.311403
# act18_composite             -0.400289   -0.404529    -0.407387 -0.311370
# sat18_participation         -0.762055   -0.791338    -0.785926 -0.353309
# sat18_read_write             1.000000    0.954661     0.988560  0.269828
# sat18_math                   0.954661    1.000000     0.988622  0.289803
# sat18_total                  0.988560    0.988622     1.000000  0.283356
# sat_diff                     0.269828    0.289803     0.283356  1.000000
# act_diff                    -0.259681   -0.283399    -0.274947 -0.805310
#
#                      act_diff
# act17_participation  0.060575
# act17_english        0.002924
# act17_math           0.003337
# act17_reading       -0.010810
# act17_science       -0.013355
# act17_composite     -0.001993
# sat17_participation -0.002442
# sat17_read_write    -0.068672
# sat17_math          -0.060136
# sat17_total         -0.064783
# act18_participation -0.337457
# act18_english        0.331062
# act18_math           0.300703
# act18_reading        0.316157
# act18_science        0.312620
# act18_composite      0.321009
# sat18_participation  0.392029
# sat18_read_write    -0.259681
# sat18_math          -0.283399
# sat18_total         -0.274947
# sat_diff            -0.805310
# act_diff             1.000000
#
# [22 rows x 22 columns]

# %%
plt.figure(figsize=(16,16))
ax = sns.heatmap(final_data.corr(), annot=True).set_title("Correlation Matrix Between ACT and SAT\n", 
                                                     fontsize=22, y=1.05)
mask =np.triu(np.ones_like(final_data.corr()))

# %% [markdown]
# > <font size = 3 color = "crimson"> Ways to improve your heatmap: <br><br> 1. Use a diagonal correlation matrix <br> 2. Explore changing the colours of the heatmap to make it more contrasting<br>  <br> https://towardsdatascience.com/annotated-heatmaps-in-5-simple-steps-cc2a0660a27d</font>

# %% [markdown]
# Looking at the correlation matrix above, we could derive the both ACT and SAT participation rate is negatively correlated to the average score of the subjects and its total for both 2017 and 2018.
# Also notice there's a negative correlation between the subjects as students would only be required to take one entrance exam

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(17,17)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column], bins = 10) # feel free to add more settings
        # Set titles, labels, etc here for each subplot
        ax[i].set_title(list_of_titles[i], fontsize=21)
        ax[i].set_ylabel('Number of States', fontsize=21)
        ax[i].set_xlabel(list_of_xlabels[i], fontsize=21)

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
#Participation rates for SAT & ACT
list_of_columns = ['sat17_participation', 'act17_participation', 'sat18_participation',
                   'act18_participation']
list_of_titles = ['SAT 2017', 'ACT 2017', 'SAT 2018', 'ACT 2018']
list_of_xlabels = ['Participation Rate', 'Participation Rate', 'Participation Rate',
                   'Participation Rate']
subplot_histograms(final_data, list_of_columns, list_of_titles, list_of_xlabels)

# %%
#Math scores for SAT & ACT
list_of_columns = ['sat17_math', 'act17_math', 'sat18_math',
                   'act18_math']
list_of_titles = ['SAT 2017', 'ACT 2017', 'SAT 2018', 'ACT 2018']
list_of_xlabels = ['Math Scores', 'Math Scores', 'Math Scores',
                   'Math Scores']
subplot_histograms(final_data, list_of_columns, list_of_titles, list_of_xlabels)

# %%
#Reading/verbal scores for SAT & ACT
list_of_columns = ['sat17_read_write', 'act17_reading', 'sat18_read_write',
                   'act18_reading']
list_of_titles = ['SAT 2017', 'ACT 2017', 'SAT 2018', 'ACT 2018']
list_of_xlabels = ['Reading/Verbal Scores', 'Reading/Verbal Scores', 'Reading/Verbal Scores',
                   'Reading/Verbal Scores']
subplot_histograms(final_data, list_of_columns, list_of_titles, list_of_xlabels)

# %% [markdown]
# > <font size = 3 color = "crimson"> Good practice to display vertical mean and median lines in your histogram as they help with interpretation of skew. Use the same scale for the y axis.</font>

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
#SAT vs. ACT math scores for 2017
ax = plt.subplots(figsize = (12,12))
ax = sns.regplot(y= 'act17_math', x= 'sat17_math', data=final_data[['act17_math', 'sat17_math']])
ax.set_title('SAT vs ACT Math Scores 2017\n', fontsize=21)
ax.set_xlabel('SAT Math', fontsize=21)
ax.set_ylabel('ACT Math', fontsize=21)
# Out:
# Text(0, 0.5, 'ACT Math')

# %% [markdown]
# > <font size = 3 color = "crimson"> Do interpret all your plots. You can adapt the histogram subplot function for scatter plots.</font>

# %%
#SAT vs. ACT verbal/reading scores for 2017
ax = plt.subplots(figsize = (12,12))
ax = sns.regplot(y= 'act17_reading', x= 'sat17_read_write', data=final_data[['act17_reading', 'sat17_read_write']])
ax.set_title('SAT vs ACT Verbal/Reading Scores 2017\n', fontsize=21)
ax.set_xlabel('SAT Read/Write', fontsize=21)
ax.set_ylabel('ACT Reading', fontsize=21)
# Out:
# Text(0, 0.5, 'ACT Reading')

# %%
#SAT vs. ACT total/composite scores for 2017
ax = plt.subplots(figsize = (12,12))
ax = sns.regplot(y= 'act17_composite', x= 'sat17_total', data=final_data[['act17_composite', 'sat17_total']])
ax.set_title('SAT vs ACT Total/Composite Scores 2017\n', fontsize=21)
ax.set_xlabel('SAT Total', fontsize=21)
ax.set_ylabel('ACT Composite', fontsize=21)
# Out:
# Text(0, 0.5, 'ACT Composite')

# %%
#Total scores for SAT 2017 vs. 2018
ax = plt.subplots(figsize = (12,12))
ax = sns.regplot(y= 'sat17_total', x= 'sat18_total', data=final_data[['sat17_total', 'sat18_total']])
ax.set_title('SAT Total Scores 2017 vs 2018\n', fontsize=21)
ax.set_xlabel('SAT 2018', fontsize=21)
ax.set_ylabel('SAT 2017', fontsize=21)
# Out:
# Text(0, 0.5, 'SAT 2017')

# %%
#Composite scores for ACT 2017 vs. 2018
ax = plt.subplots(figsize = (12,12))
ax = sns.regplot(y= 'act17_composite', x= 'act18_composite', data=final_data[['act17_composite', 'act18_composite']])
ax.set_title('ACT Composite Scores 2017\n', fontsize=21)
ax.set_xlabel('ACT 2018', fontsize=21)
ax.set_ylabel('ACT 2017', fontsize=21)
# Out:
# Text(0, 0.5, 'ACT 2017')

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
#Box plot Sat Scores
ax = plt.subplots(figsize=(16,12))
plt.title('SAT Scores 2017 and 2018', fontsize=28)
plt.ylabel('Score', fontsize=20)
plt.ylim(400, 800)

sns.boxplot(data=final_data[['sat17_read_write','sat17_math', 'sat18_read_write', 
                       'sat18_math']], width=0.7)

# %%
#Box plot Act Scores 2017 and 2018
ax = plt.subplots(figsize=(15,10))
plt.title('ACT Scores 2017 and 2018', fontsize=28)
plt.ylabel('Score', fontsize=20)
plt.ylim(15, 27)

sns.boxplot(data=final_data[['act17_english', 'act17_math', 'act17_reading', 
                       'act17_science', 'act18_english', 'act18_math', 'act18_reading', 'act18_science']]
            , width=0.7)

# %%
#Box plot Participation Rate
ax = plt.subplots(figsize=(18,12))
plt.title('Participation of SAT and ACT', fontsize=26)
plt.ylabel('Participation Rate', fontsize=20)
plt.ylim(0, 1.2)

sns.boxplot(data=final_data[['sat17_participation', 'sat18_participation', 'act17_participation', 
                       'act18_participation']], width=0.7)

# %% [markdown]
# > <font size = 3 color = "crimson"> Do interpret all your plots and make the labels bigger.</font>

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
avg_income = pd.read_csv('../data/avg_income.csv')

# %%
data_income = pd.merge(final_data, avg_income, on='state', how='left')
data_income.head()
# Out:
#         state  act17_participation  act17_english  act17_math  act17_reading  \
# 0     Alabama                 1.00           18.9        18.4           19.7
# 1      Alaska                 0.65           18.7        19.8           20.4
# 2     Arizona                 0.62           18.6        19.8           20.1
# 3    Arkansas                 1.00           18.9        19.0           19.7
# 4  California                 0.31           22.5        22.7           23.1
#
#    act17_science  act17_composite  sat17_participation  sat17_read_write  \
# 0           19.4             19.2                 0.05               593
# 1           19.9             19.8                 0.38               547
# 2           19.8             19.7                 0.30               563
# 3           19.5             19.4                 0.03               614
# 4           22.2             22.8                 0.53               531
#
#    sat17_math  ...  act18_science  act18_composite  sat18_participation  \
# 0         572  ...           19.0             19.1                 0.06
# 1         533  ...           20.7             20.8                 0.43
# 2         553  ...           19.2             19.2                 0.29
# 3         594  ...           19.4             19.4                 0.05
# 4         524  ...           22.1             22.7                 0.60
#
#    sat18_read_write  sat18_math  sat18_total  sat_diff  act_diff  \
# 0               595         571         1166     -0.01      0.00
# 1               562         544         1106     -0.05      0.32
# 2               577         572         1149      0.01     -0.04
# 3               592         576         1169     -0.02      0.00
# 4               540         536         1076     -0.07      0.04
#
#    median_income18  median_income17
# 0        49,861.00        48,123.00
# 1        74,346.00        73,181.00
# 2        59,246.00        56,581.00
# 3        47,062.00        45,869.00
# 4        75,277.00        71,805.00
#
# [5 rows x 25 columns]

# %%
data_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state                51 non-null     object
#  1   act17_participation  51 non-null     float64
#  2   act17_english        51 non-null     float64
#  3   act17_math           51 non-null     float64
#  4   act17_reading        51 non-null     float64
#  5   act17_science        51 non-null     float64
#  6   act17_composite      51 non-null     float64
#  7   sat17_participation  51 non-null     float64
#  8   sat17_read_write     51 non-null     int64
#  9   sat17_math           51 non-null     int64
#  10  sat17_total          51 non-null     int64
#  11  act18_participation  51 non-null     float64
#  12  act18_english        51 non-null     float64
#  13  act18_math           51 non-null     float64
#  14  act18_reading        51 non-null     float64
#  15  act18_science        51 non-null     float64
#  16  act18_composite      51 non-null     float64
#  17  sat18_participation  51 non-null     float64
#  18  sat18_read_write     51 non-null     int64
#  19  sat18_math           51 non-null     int64
#  20  sat18_total          51 non-null     int64
#  21  sat_diff             51 non-null     float64
#  22  act_diff             51 non-null     float64
#  23  median_income18      51 non-null     object
#  24  median_income17      51 non-null     object
# dtypes: float64(16), int64(6), object(3)
# memory usage: 10.4+ KB

# %%
#Noted median income column for 2017 and 2018 are object, remove string
data_income['median_income17'] = data_income['median_income17'].map(lambda part: part.replace(',',''))
data_income['median_income18'] = data_income['median_income18'].map(lambda part: part.replace(',',''))

# %%
#Changed datatype to float
data_income['median_income17'] = data_income['median_income17'].astype(float)
data_income['median_income18'] = data_income['median_income18'].astype(float)

# %%
# Check the column to ensure format is correct
data_income['median_income17'].head(5)
# Out:
# 0    48123.0
# 1    73181.0
# 2    56581.0
# 3    45869.0
# 4    71805.0
# Name: median_income17, dtype: float64

# %%
x = plt.subplots(figsize = (12,12))
x = sns.regplot(y= 'median_income18', x= 'sat18_participation', 
                data=data_income[['median_income18', 'sat18_participation']])
x.set_title(' SAT Participation By Household Income 2018\n', fontsize=21)
x.set_xlabel('Participation', fontsize=21)
x.set_ylabel('Median Income', fontsize=21)
# Out:
# Text(0, 0.5, 'Median Income')

# %%
x = plt.subplots(figsize = (12,12))
x = sns.regplot(y= 'median_income17', x= 'sat17_participation', 
                data=data_income[['median_income17', 'sat17_participation']])
x.set_title(' SAT Participation By Household Income 2017\n', fontsize=21)
x.set_xlabel('Participation', fontsize=21)
x.set_ylabel('Median Income', fontsize=21)
# Out:
# Text(0, 0.5, 'Median Income')

# %% [markdown]
# Included the median household income by state for 2017 and 2018.
# Point of the scatter plot is to see the correlation between high school children from low income families and the SAT participation rate.
# Year over year, we notice the income of each household plays an important factor in the participation rate of the SAT entrance exams as from the scatter plot above we see both 2017 and 2018 skewed to the right.
# The lower the household income the particpation rate will decline further.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
final_data.describe().T
# Out:
#                      count         mean        std     min       25%      50%  \
# act17_participation   51.0     0.652549   0.321408    0.08     0.310     0.69
# act17_english         51.0    20.931373   2.353677   16.30    19.000    20.70
# act17_math            51.0    21.182353   1.981989   18.00    19.400    20.90
# act17_reading         51.0    22.013725   2.067271   18.10    20.450    21.80
# act17_science         51.0    21.462745   1.753392   18.20    19.950    21.30
# act17_composite       51.0    21.519608   2.020695   17.80    19.800    21.40
# sat17_participation   51.0     0.398039   0.352766    0.02     0.040     0.38
# sat17_read_write      51.0   569.117647  45.666901  482.00   533.500   559.00
# sat17_math            51.0   556.882353  47.121395  468.00   523.500   548.00
# sat17_total           51.0  1126.098039  92.494812  950.00  1055.500  1107.00
# act18_participation   51.0     0.616471   0.340810    0.07     0.285     0.66
# act18_english         51.0    20.988235   2.446356   16.60    19.100    20.20
# act18_math            51.0    21.125490   2.035765   17.80    19.400    20.70
# act18_reading         51.0    22.015686   2.167245   18.00    20.450    21.60
# act18_science         51.0    21.345098   1.870114   17.90    19.850    21.10
# act18_composite       51.0    21.486275   2.106278   17.70    19.950    21.30
# sat18_participation   51.0     0.457451   0.373143    0.02     0.045     0.52
# sat18_read_write      51.0   563.686275  47.502627  480.00   534.500   552.00
# sat18_math            51.0   556.235294  47.772623  480.00   522.500   544.00
# sat18_total           51.0  1120.019608  94.155083  977.00  1057.500  1098.00
# sat_diff              51.0    -0.059412   0.182717   -0.90    -0.050    -0.01
# act_diff              51.0     0.036078   0.134478   -0.25     0.000     0.01
#
#                           75%      max
# act17_participation     1.000     1.00
# act17_english          23.300    25.50
# act17_math             23.100    25.30
# act17_reading          24.150    26.00
# act17_science          23.200    24.90
# act17_composite        23.600    25.50
# sat17_participation     0.660     1.00
# sat17_read_write      613.000   644.00
# sat17_math            599.000   651.00
# sat17_total          1212.000  1295.00
# act18_participation     1.000     1.00
# act18_english          23.700    26.00
# act18_math             23.150    25.20
# act18_reading          24.100    26.10
# act18_science          23.050    24.90
# act18_composite        23.550    25.60
# sat18_participation     0.775     1.00
# sat18_read_write      610.500   643.00
# sat18_math            593.500   655.00
# sat18_total          1204.000  1298.00
# sat_diff                0.000     0.27
# act_diff                0.040     0.70

# %% [markdown]
# > <font size = 3 color = "crimson"> Do provide a written answer for this part.</font>

# %% [markdown]
# Answers:

# %% [markdown]
# #### Distributions in the data
#
# In this dataset, each data represents a sample from a population.
# For example, for ACT math test:
# - Population: the test results of all the students who take this test, nation-wide.
# - Population mean: is the national average of ACT math test (total scores/total no. of test takers)
# - Sample: the state means of ACT math test. We have 51 samples (51 states)
#
# ***According to CLT, we generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?***

# %% [markdown]
# Answer: No, as per the histogram bar chart we dont see a normal distribution in the sample population provided.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# For Math and Reading score we see the values are much more closer to the mean compared to participation rates which is mostly skewed to the left or right depending on the states. With increase in sampling size we would see Math and Reading becoming normally distributed.

# %% [markdown]
#  <font size = 3 color = "crimson"> *Defining the terms in the context of this dataset:*
# - Population - total nationwide high school seniors that took SAT and/or ACT in a particular year
# - Number of samples - 51 samples (Total number of states)
# - Sample size - varies by number of participants in each state, and therefore each sample's mean is calculated against different totals.
#
# From the data visualisations done so far, none of the data variables follow a normal distribution. <br>
# This is because of a few reasons:
# - The sampling done from the population is not random, as it is influenced by outside factors such as state legislation, contracts with schools etc.
# - The size of the sample is not constant. Each state has varying participation rates which are also derived from varying number of total high school seniors taking SAT and/or ACT. Therefore the variance in sample size is very high.
# - The number of samples (51) is too low.
#
# For the normality assumption to hold true:
# - The sampling has to be random (i.e. no arbritary constraints imposed on the sampling process such as legislation)
# - The number of samples has to be big enough.
# - The sample size ideally should be constant. </font>

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Conducting the statistical inference for both test ACT and SAT in 2017, will only be useful in identifying states that have higher participation rate in their respective entrance exams.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores  - can we say students with higher SAT math score is better than those with lower ACT math score, or vice versa?
#
# Why or why not?

# %% [markdown]
# I dont think its approriate, as their score range is different as ACT is between 1 and 36 while SAT is between 400 and 800.
# Along with different grading methodoligy, this wont make an accurate comparison.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Based on my observations from the data sets above, I notice three states Illinois, Colorado and Rhode Island showing interesting trends in in their SAT participation rates.
#
# Illinois, Colorado and Rhode Island has seen a 90%, 89% and 26% increase year over year from 2017 to 2018. This is mainly due to the new implementation by states which makes SAT an mandatory requirement for their high school children from 2017 onwards.
#
# With this new mandate, high school children wont have to pay 138 dollars for the test, opening the door for children from low income families to participate in the tests.
# This can been in the scatter plot above, where I have included the median household income by state for 2017 and 2018. Point of the scatter plot is to see the correlation between high school children from low income families and the SAT participation rate. Year over year, we notice the income of each household plays an important factor in the participation rate of the SAT entrance exams as from the scatter plot above we see both 2017 and 2018 skewed to the right. The lower the household income the particpation rate will decline further.
# Unlike participation rates, most of the grade scores for both ACT and SAT test in the Histogram above are located closer to the mean in 2017 and 2018 with slight change in standard deviation.
#
# As per 2018 ACT participation figures, Colorado and Illinois delcine 70% and 50% respectively.
# This shows how much influence state goverments can have over participation rates in either for college entrance exams. As per correlation matrix above, we could derive the both ACT and SAT participation rate is negatively correlated to the average score of the subjects and its total for both 2017 and 2018.
#
# Ref:
#
# https://www.cnbc.com/2019/10/03/rich-students-get-better-sat-scores-heres-why.html
# https://www.chicagotribune.com/news/breaking/ct-parcc-test-high-school-met-20160711-story.html
# https://www.cnbc.com/2019/10/03/rich-students-get-better-sat-scores-heres-why.html
# https://www.testive.com/colorado-sat-change-2017/
# https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_income

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Base on the research above, we can see how much of influence the state goverment has over the participation rate of either SAT or ACT entrance exams.
# There are currently 13 states who require their high school children to participate for ACT entrance exam and 20 states who states who require their high school children to participate for SAT entrance exam.
# College board could work with state governments whose participation rates are below average for example South Dakota who have not made ACT an madatory requirment for their high school children to take the entrance exam.
#
# Ref:
#
# https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice
# https://blog.prepscholar.com/which-states-require-the-sat
